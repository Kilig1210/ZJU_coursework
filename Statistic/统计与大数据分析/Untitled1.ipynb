# %%
# import geopandas as gpd
# import matplotlib.pyplot as plt

# # 读取地理位置信息数据（例如Shapefile文件）
# # 在这个例子中，使用geopandas提供的自带的世界地图数据
# world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# # 绘制世界地图
# world.plot()

# # 显示地图
# plt.show()


# # 记得安装相关库
# # pip install pyecharts
# # pip install echarts-countries-pypkg
# # pip install echarts-china-provinces-pypkg
# # pip install echarts-china-cities-pypkg
# # pip install echarts-china-counties-pypkg
# # pip install fsspec
# import pandas as pd
# from pyecharts import options as opts
# from pyecharts.charts import Geo
# from pyecharts.globals import ChartType

# # 修正文件路径
# file_path = r"D:\统计与大数据分析\期末大作业\owid-energy-data .csv"  # 使用原始字符串
# data = pd.read_csv(file_path, encoding='utf-8')

# # 删除包含 NaN 值的行
# data = data.dropna(subset=["country", "gdp"])

# country = list(data["country"])
# gdp = list(data["gdp"])
# data_list = [list(z) for z in zip(country, gdp)]

# # 打印组合后的列表
# print(data_list)


# valid_countries = [country for country in countries_data_set if country in COORDINATES_MAP]

# # 创建地图
# c = (
#     Geo()
#     .add_schema(maptype="world")
#     .add(
#         "geo",
#         data_list,  # 传入数据
#         symbol_size=10,
#         type_=ChartType.EFFECT_SCATTER,   # 地图类型为涟漪图
#     )
#     .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
#     .set_global_opts(
#         visualmap_opts=opts.VisualMapOpts(max_=max(gdp)),  # 使用最大GDP值作为visual map的上限
#         title_opts=opts.TitleOpts(title="各国GDP涟漪图")
#     )
#     .render("Geomap1.html")
# )

# %%
# # 七大洲数据
# continents = ['Africa', 'Antarctica', 'Asia', 'Europe', 'North America', 'Oceania', 'South America']
# # 筛选数据
# filtered_data_continents = df[(df['country'].isin(continents)) & (df['year'] >= 1993) & (df['year'] <= 2022)]

# # 进行描述统计
# description_continents = filtered_data_continents.describe()
# # 打印描述统计结果
# print(description_continents)
